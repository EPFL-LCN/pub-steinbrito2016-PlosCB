# %%
import fig2

# %%
# generate the whitening filter and save to file
# natural images from O&F 1996: https://people.eecs.berkeley.edu/~efros/courses/AP06/Papers/code/olshausen-nature-96/
fig2.oef_whiten_patchfilter()

# %%
# learn the receptive fields for each nonlinearity and save to file
# very slow for nonlinearity #13
# uses single small learning rate for all nonlinearites, which could be optimized
# iis is nonlinearity selection
fig2.trial(iis = range(0,20))

# %%
# plot the receptive fields and save to file
fig = fig2.plot_2c()
fig.savefig('fig2c.png', dpi=300, bbox_inches='tight');
